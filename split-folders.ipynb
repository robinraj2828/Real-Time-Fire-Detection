# %% [markdown]
# **Split folders into train-test-val**

# %%
pip install split-folders

# %%
import splitfolders
import os

os.mkdir('./final_FD_images/')

splitfolders.ratio('/kaggle/input/datapreprocessing/FD_data/', output='./final_FD_images/', seed=1337, ratio=(.7,.1,.2))
